# %% [markdown]
# # 🧪 LNP Predictor Colab Notebook
# This notebook predicts lipid nanoparticle (LNP) properties using trained machine learning models.
#
# You must have uploaded the following files to your Google Drive:
# - `rf_model_size.pkl`
# - `rf_model_empty.pkl`
# - `rf_model_RNA_pooled_CV.pkl`
# - `scaler_size.pkl`, `scaler_empty.pkl`, `scaler_RNA_pooled_CV.pkl`
# - `lnp_radius_vs_time.csv`
# - `read_trained_predict.py` (main script)
#
# Folder path: `/MyDrive/LNP_Predictor_Colab/`

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys

MODEL_DIR = "/content/drive/MyDrive/LNP_Predictor_Colab"
os.chdir(MODEL_DIR)
sys.path.append(MODEL_DIR)

# %%
# !python read_trained_predict_modified.py
# Out:
# Enter experimental conditions:
# Flow rate Q (mL/min): 20
# PEG molecular weight (Da): 2342
# PEG ratio (e.g. 0.015): .032
# Salt concentration (Mol): .019
#  τ_M (charachteristic mixing time) = 0.007822 s
#  Interpolated LNP Radius at τ_M: 8.9077 nm
# 🧪 Flory radius RF = 4.0168 nm
#
#  Predicting LNP properties...
#  size prediction: 17.7773
#  empty prediction: 0.5647
#  RNA_pooled_CV prediction: 2.3396
